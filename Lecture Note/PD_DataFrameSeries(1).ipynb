# %%
from pandas import Series, DataFrame

kakao = Series([92600, 92400, 92100, 94300, 92300])
print(kakao)
# Out:
# 0    92600
# 1    92400
# 2    92100
# 3    94300
# 4    92300
# dtype: int64

# %%
kakao2 = Series([92600, 92400, 92100, 94300, 92300], index=['2017-03-03',
               '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09'])
print(kakao2)
# Out:
# 2017-03-03    92600
# 2017-03-06    92400
# 2017-03-07    92100
# 2017-03-08    94300
# 2017-03-09    92300
# dtype: int64

# %%
print(kakao2['2017-03-09'])
# Out:
# 92300

# %%
import pandas as pd
kakao2 = Series([92600, 92400, 92100, 94300, 92300], index=pd.date_range("20170303", freq="B", periods=5))
print(kakao2)
# Out:
# 2017-03-03    92600
# 2017-03-06    92400
# 2017-03-07    92100
# 2017-03-08    94300
# 2017-03-09    92300
# Freq: B, dtype: int64

# %%
import pandas as pd
kakao2 = Series([92600, 92400, 92100, 94300, 92300], index=pd.date_range("20170303","20170309", freq="B"))
print(kakao2)
# Out:
# 2017-03-03    92600
# 2017-03-06    92400
# 2017-03-07    92100
# 2017-03-08    94300
# 2017-03-09    92300
# Freq: B, dtype: int64

# %%
# %matplotlib nbagg
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np
kakao2 = Series([92600, 92400, 92100, 94300, 92300], index=['2017-03-03',
               '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09'])
kakao2.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
for date in kakao2.index:
    print(date)

for ending_price in kakao2.values:
    print(ending_price)
# Out:
# 2017-03-03
# 2017-03-06
# 2017-03-07
# 2017-03-08
# 2017-03-09
# 92600
# 92400
# 92100
# 94300
# 92300

# %%
mine   = Series([10, 20, 30], index=['naver', 'sk', 'kt'])
friend = Series([10, 30, 20], index=['kt', 'naver', 'sk'])
merge = mine + friend
print(merge)
# Out:
# kt       40
# naver    40
# sk       40
# dtype: int64

# %%
raw_data = {'col0': [1, 2, 3, 4],
            'col1': [10, 20, 30, 40],
            'col2': [100, 200, 300, 400]}

data = DataFrame(raw_data)
print(data)
# Out:
#    col0  col1  col2
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400

# %%
data['col0']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col0, dtype: int64

# %%
type(data['col0'])
# Out:
# pandas.core.series.Series

# %%
daeshin = {'open':  [11650, 11100, 11200, 11100, 11000],
           'high':  [12100, 11800, 11200, 11100, 11150],
           'low' :  [11600, 11050, 10900, 10950, 10900],
           'close': [11900, 11600, 11000, 11100, 11050]}

daeshin_day = DataFrame(daeshin)
print(daeshin_day)
# Out:
#     open   high    low  close
# 0  11650  12100  11600  11900
# 1  11100  11800  11050  11600
# 2  11200  11200  10900  11000
# 3  11100  11100  10950  11100
# 4  11000  11150  10900  11050

# %%
daeshin_day = DataFrame(daeshin, columns=['open', 'high', 'low', 'close'])
print(daeshin_day)
# Out:
#     open   high    low  close
# 0  11650  12100  11600  11900
# 1  11100  11800  11050  11600
# 2  11200  11200  10900  11000
# 3  11100  11100  10950  11100
# 4  11000  11150  10900  11050

# %%
date = ['16.02.29', '16.02.26', '16.02.25', '16.02.24', '16.02.23']
daeshin_day = DataFrame(daeshin, columns=['open', 'high', 'low', 'close'], index=date)
print(daeshin_day)
daeshin_day.plot(title="DaeShin")
daeshin_day.plot(kind='barh', title="DaeShin ")
# Out:
#            open   high    low  close
# 16.02.29  11650  12100  11600  11900
# 16.02.26  11100  11800  11050  11600
# 16.02.25  11200  11200  10900  11000
# 16.02.24  11100  11100  10950  11100
# 16.02.23  11000  11150  10900  11050
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
close = daeshin_day['close']
print(close)
# Out:
# 16.02.29    11900
# 16.02.26    11600
# 16.02.25    11000
# 16.02.24    11100
# 16.02.23    11050
# Name: close, dtype: int64

# %%
day_data = daeshin_day.ix['16.02.24']
print(day_data)
print(type(day_data))
# Out:
# open     11100
# high     11100
# low      10950
# close    11100
# Name: 16.02.24, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(daeshin_day.columns)
print(daeshin_day.index)
# Out:
# Index(['open', 'high', 'low', 'close'], dtype='object')
# Index(['16.02.29', '16.02.26', '16.02.25', '16.02.24', '16.02.23'], dtype='object')

# %%
import pandas_datareader.data as web
